# %%
print('Hello world!')
# Out:
# Hello world!

# %%
a=5
b=6
print(a/b)
print(b/a)
# Out:
# 0.8333333333333334
# 1.2

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(float(1000))
y = x

plt.plot(x, y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(float(1000))
y = x

fig, ax = plt.subplots()
ax.plot(x, y)
ax.plot(x, x**2,color='r')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = (np.arange(float(2000))-1000)/500
print(x)
y = x
plt.plot(x,y)
plt.show()
# Out:
# [-2.    -1.998 -1.996 ...  1.994  1.996  1.998]

# %%
import numpy as np
import matplotlib.pyplot as plt

#np.random.seed(12)
data = np.random.rand(1000)
plt.plot(data) 
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

#np.random.seed(12)
data = np.random.randn(1000)
plt.plot(data) 
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

#np.random.seed(12)
data = np.random.rand(1000)
plt.plot(data, '.') 
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

#np.random.seed(12)
data = np.random.randn(1000)
plt.plot(data, '.') 
plt.show()
